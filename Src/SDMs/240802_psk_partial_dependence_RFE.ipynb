# %%
import os #create directories 
from matplotlib import pyplot as plt #ploting data 
import matplotlib.pylab as pl
import rasterio #reading data
import shapely #geometric operations 
import pandas as pd
import numpy as np
import shap

import glob
import pickle
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
os.chdir("/Users/pranavkulkarni/SDM/Climate_Models_Arenaviruses")
os.getcwd()
# Out:
# '/Users/pranavkulkarni/SDM/Climate_Models_Arenaviruses'

# %%
with open('./Data/Output/iterations/Z_brevicauda/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
pd_list
# Out:
# [[    Mean Diurnal Range_grid  Mean Diurnal Range_avg
#   0                 20.528541                0.562694
#   1                 20.604420                0.562694
#   2                 20.680299                0.562694
#   3                 20.756178                0.562694
#   4                 20.832058                0.562694
#   ..                      ...                     ...
#   95                27.737052                0.562694
#   96                27.812931                0.562694
#   97                27.888810                0.562694
#   98                27.964689                0.562694
#   99                28.040568                0.562694
#
#   [100 rows x 2 columns],
#       Isothermality_grid  Isothermality_avg
#   0             7.290945           0.613304
#   1             7.330329           0.611211
#   2             7.369714           0.612820
#   3             7.409098           0.616056
#   4             7.448483           0.611609
# ...

# %%
pd.DataFrame(pd_list[0][0])
# Out:
#     Mean Diurnal Range_grid  Mean Diurnal Range_avg
# 0                 20.528541                0.562694
# 1                 20.604420                0.562694
# 2                 20.680299                0.562694
# 3                 20.756178                0.562694
# 4                 20.832058                0.562694
# ..                      ...                     ...
# 95                27.737052                0.562694
# 96                27.812931                0.562694
# 97                27.888810                0.562694
# 98                27.964689                0.562694
# 99                28.040568                0.562694
#
# [100 rows x 2 columns]

# %%
for id, it in enumerate(pd_list):
    print(len(it[3]))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
if os.path.exists("./Data/Output/iterations/Z_brevicauda/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/Z_brevicauda/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/Z_brevicauda/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")

# %%
with open('./Data/Output/iterations/S_alstoni/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
if os.path.exists("./Data/Output/iterations/S_alstoni/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/S_alstoni/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/S_alstoni/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")

# %%
with open('./Data/Output/iterations/C_callosus/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
if os.path.exists("./Data/Output/iterations/C_callosus/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/C_callosus/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/C_callosus/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")

# %%
with open('./Data/Output/iterations/C_musculinus/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
if os.path.exists("./Data/Output/iterations/C_musculinus/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/C_musculinus/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/C_musculinus/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")

# %%
with open('./Data/Output/iterations/C_laucha/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
if os.path.exists("./Data/Output/iterations/C_laucha/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/C_laucha/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/C_laucha/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")

# %%
with open('./Data/Output/iterations/O_flavescens/pd_results.pkl', 'rb') as f:
    pd_list = pickle.load(f)

# %%
if os.path.exists("./Data/Output/iterations/O_flavescens/partial_dependence/RFE"):
    print('name folders exists')
else: 
    os.mkdir("./Data/Output/iterations/O_flavescens/partial_dependence/RFE")

for i in range(len(pd_list)):
    a = pd_list[i].copy()
    a = pd.concat(a, axis = 1)
    
    a.to_csv("./Data/Output/iterations/O_flavescens/partial_dependence/RFE/" + "pd_" + str(i) + ".csv")
