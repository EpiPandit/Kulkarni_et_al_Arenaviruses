# %%
setwd("/Users/pranavkulkarni/SDM/Climate_Models_Arenaviruses")

library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
zyg_fi <- read.csv("./Data/Output/iterations/Z_brevicauda/fi_summary.csv")
sig_fi <- read.csv("./Data/Output/iterations/S_alstoni/fi_summary.csv")

ccal_fi <- read.csv("./Data/Output/iterations/C_callosus/fi_summary.csv")

cmus_fi <- read.csv("./Data/Output/iterations/C_musculinus/fi_summary.csv")
cla_fi <- read.csv("./Data/Output/iterations/C_laucha/fi_summary.csv")
ofl_fi <- read.csv("./Data/Output/iterations/O_flavescens/fi_summary.csv")

# %%
zyg <- ggplot(zyg_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "blue", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() + labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

sig <- ggplot(sig_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "red", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() +labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

ccal <- ggplot(ccal_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "violet", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() +labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

cmus <- ggplot(cmus_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "brown", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() +labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

cla <- ggplot(cla_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "yellow", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() +labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

ofl <- ggplot(ofl_fi, aes(x = reorder(X,n_sel_RFE), y = n_sel_RFE)) + 
  stat_identity(geom = "bar", fill = "green", color = "black") + 
  stat_identity(aes(label = round(mean_fi_RFE,3)), geom = "label", size = rel(2)) +
  coord_flip() +labs(y = "No. selected in RFE", x = "Features" ) +
  theme_classic()

# %%
ggpubr::ggarrange(zyg, sig, ccal, cmus, cla, ofl, 
                  ncol = 2, nrow = 3, 
                  labels = c("Z_brevicauda", "S_alstoni", "C_callosus",
                             "C_musculinus", "C_laucha", "O_flavescens"), 
                  vjust = 1, hjust = -1)
# Out:
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range
# (`geom_label()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_label()`).”
# Warning message:
# “Removed 6 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# Warning message:
# “Removed 6 rows containing missing values or values outside the scale range
# (`geom_label()`).”
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range
# (`geom_bar()`).”
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range
# (`geom_label()`).”
# Warning message:
# ...
